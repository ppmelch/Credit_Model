# %% [markdown]
# # Libraries

# %%
import kagglehub
import os
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ---

# %%
# Download latest version
path = kagglehub.dataset_download("parthpatel2130/realistic-loan-approval-dataset-us-and-canada")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: C:\Users\ppmel\.cache\kagglehub\datasets\parthpatel2130\realistic-loan-approval-dataset-us-and-canada\versions\1

# %%
print(os.listdir(path))
# Out:
# ['Loan_approval_data_2025.csv']

# %%
df = pd.read_csv(path + "/Loan_approval_data_2025.csv")
df
# Out:
#       customer_id  age occupation_status  years_employed  annual_income  \
# 0      CUST100000   40          Employed            17.2          25579
# 1      CUST100001   33          Employed             7.3          43087
# 2      CUST100002   42           Student             1.1          20840
# 3      CUST100003   53           Student             0.5          29147
# 4      CUST100004   32          Employed            12.5          63657
# ...           ...  ...               ...             ...            ...
# 49995  CUST149995   35          Employed             4.3          39449
# 49996  CUST149996   34          Employed             4.4          20496
# 49997  CUST149997   41     Self-Employed             4.8          18743
# 49998  CUST149998   38           Student             0.4          17250
# 49999  CUST149999   53          Employed            17.2          46923
#
#        credit_score  credit_history_years  savings_assets  current_debt  \
# 0               692                   5.3             895         10820
# 1               627                   3.5             169         16550
# 2               689                   8.4              17          7852
# 3               692                   9.8            1480         11603
# 4               630                   7.2             209         12424
# ...             ...                   ...             ...           ...
# 49995           570                  16.3            1127          7576
# 49996           672                  12.6            1478          6276
# 49997           719                  10.1              17         10331
# 49998           633                   1.3               5          7779
# 49999           695                  15.0            8332          2655
#
#        defaults_on_file  delinquencies_last_2yrs  derogatory_marks  \
# 0                     0                        0                 0
# 1                     0                        1                 0
# 2                     0                        0                 0
# 3                     0                        1                 0
# 4                     0                        0                 0
# ...                 ...                      ...               ...
# 49995                 0                        0                 0
# 49996                 1                        0                 0
# 49997                 0                        0                 0
# 49998                 0                        0                 1
# 49999                 0                        1                 0
#
#         product_type         loan_intent  loan_amount  interest_rate  \
# 0        Credit Card            Business          600          17.02
# 1      Personal Loan    Home Improvement        53300          14.10
# 2        Credit Card  Debt Consolidation         2100          18.33
# 3        Credit Card            Business         2900          18.74
# 4      Personal Loan           Education        99600          13.92
# ...              ...                 ...          ...            ...
# 49995    Credit Card           Education        42800          21.31
# 49996    Credit Card            Personal         3800          18.07
# 49997    Credit Card            Personal        18000          17.45
# 49998  Personal Loan            Personal         1400          14.71
# 49999  Personal Loan            Personal        41000          12.39
#
#        debt_to_income_ratio  loan_to_income_ratio  payment_to_income_ratio  \
# 0                     0.423                 0.023                    0.008
# 1                     0.384                 1.237                    0.412
# 2                     0.377                 0.101                    0.034
# 3                     0.398                 0.099                    0.033
# 4                     0.195                 1.565                    0.522
# ...                     ...                   ...                      ...
# 49995                 0.192                 1.085                    0.362
# 49996                 0.306                 0.185                    0.062
# 49997                 0.551                 0.960                    0.320
# 49998                 0.451                 0.081                    0.027
# 49999                 0.057                 0.874                    0.291
#
#        loan_status
# 0                1
# 1                0
# 2                1
# 3                1
# 4                1
# ...            ...
# 49995            0
# 49996            0
# 49997            0
# 49998            0
# 49999            1
#
# [50000 rows x 20 columns]

# %%
df.copy()
# Out:
#       customer_id  age occupation_status  years_employed  annual_income  \
# 0      CUST100000   40          Employed            17.2          25579
# 1      CUST100001   33          Employed             7.3          43087
# 2      CUST100002   42           Student             1.1          20840
# 3      CUST100003   53           Student             0.5          29147
# 4      CUST100004   32          Employed            12.5          63657
# ...           ...  ...               ...             ...            ...
# 49995  CUST149995   35          Employed             4.3          39449
# 49996  CUST149996   34          Employed             4.4          20496
# 49997  CUST149997   41     Self-Employed             4.8          18743
# 49998  CUST149998   38           Student             0.4          17250
# 49999  CUST149999   53          Employed            17.2          46923
#
#        credit_score  credit_history_years  savings_assets  current_debt  \
# 0               692                   5.3             895         10820
# 1               627                   3.5             169         16550
# 2               689                   8.4              17          7852
# 3               692                   9.8            1480         11603
# 4               630                   7.2             209         12424
# ...             ...                   ...             ...           ...
# 49995           570                  16.3            1127          7576
# 49996           672                  12.6            1478          6276
# 49997           719                  10.1              17         10331
# 49998           633                   1.3               5          7779
# 49999           695                  15.0            8332          2655
#
#        defaults_on_file  delinquencies_last_2yrs  derogatory_marks  \
# 0                     0                        0                 0
# 1                     0                        1                 0
# 2                     0                        0                 0
# 3                     0                        1                 0
# 4                     0                        0                 0
# ...                 ...                      ...               ...
# 49995                 0                        0                 0
# 49996                 1                        0                 0
# 49997                 0                        0                 0
# 49998                 0                        0                 1
# 49999                 0                        1                 0
#
#         product_type         loan_intent  loan_amount  interest_rate  \
# 0        Credit Card            Business          600          17.02
# 1      Personal Loan    Home Improvement        53300          14.10
# 2        Credit Card  Debt Consolidation         2100          18.33
# 3        Credit Card            Business         2900          18.74
# 4      Personal Loan           Education        99600          13.92
# ...              ...                 ...          ...            ...
# 49995    Credit Card           Education        42800          21.31
# 49996    Credit Card            Personal         3800          18.07
# 49997    Credit Card            Personal        18000          17.45
# 49998  Personal Loan            Personal         1400          14.71
# 49999  Personal Loan            Personal        41000          12.39
#
#        debt_to_income_ratio  loan_to_income_ratio  payment_to_income_ratio  \
# 0                     0.423                 0.023                    0.008
# 1                     0.384                 1.237                    0.412
# 2                     0.377                 0.101                    0.034
# 3                     0.398                 0.099                    0.033
# 4                     0.195                 1.565                    0.522
# ...                     ...                   ...                      ...
# 49995                 0.192                 1.085                    0.362
# 49996                 0.306                 0.185                    0.062
# 49997                 0.551                 0.960                    0.320
# 49998                 0.451                 0.081                    0.027
# 49999                 0.057                 0.874                    0.291
#
#        loan_status
# 0                1
# 1                0
# 2                1
# 3                1
# 4                1
# ...            ...
# 49995            0
# 49996            0
# 49997            0
# 49998            0
# 49999            1
#
# [50000 rows x 20 columns]

# %%
df['product_type'].unique()
# Out:
# array(['Credit Card', 'Personal Loan', 'Line of Credit'], dtype=object)

# %%
df = df[~df['product_type'].isin(['Credit Card', 'Line of Credit'])]

# %%
df = df.drop(columns= ["customer_id"])

# %%
#df.to_csv("dataset.csv")

# %%
df
# Out:
#        age occupation_status  years_employed  annual_income  credit_score  \
# 1       33          Employed             7.3          43087           627
# 4       32          Employed            12.5          63657           630
# 6       53          Employed            22.9          44989           674
# 19      18     Self-Employed             1.0          55309           597
# 20      52          Employed            31.3          75932           695
# ...    ...               ...             ...            ...           ...
# 49987   34          Employed             5.3          32326           678
# 49992   30          Employed             9.3          24797           610
# 49994   18          Employed             0.0          64343           585
# 49998   38           Student             0.4          17250           633
# 49999   53          Employed            17.2          46923           695
#
#        credit_history_years  savings_assets  current_debt  defaults_on_file  \
# 1                       3.5             169         16550                 0
# 4                       7.2             209         12424                 0
# 6                      11.1           19667         19298                 0
# 19                      1.5             346          2930                 0
# 20                      2.1            1283         10655                 0
# ...                     ...             ...           ...               ...
# 49987                  14.7             585         12320                 0
# 49992                   8.3              16          6282                 0
# 49994                   1.3             277         27914                 0
# 49998                   1.3               5          7779                 0
# 49999                  15.0            8332          2655                 0
#
#        delinquencies_last_2yrs  derogatory_marks   product_type  \
# 1                            1                 0  Personal Loan
# 4                            0                 0  Personal Loan
# 6                            0                 0  Personal Loan
# 19                           0                 0  Personal Loan
# 20                           0                 0  Personal Loan
# ...                        ...               ...            ...
# 49987                        0                 0  Personal Loan
# 49992                        1                 0  Personal Loan
# 49994                        0                 2  Personal Loan
# 49998                        0                 1  Personal Loan
# 49999                        1                 0  Personal Loan
#
#               loan_intent  loan_amount  interest_rate  debt_to_income_ratio  \
# 1        Home Improvement        53300          14.10                 0.384
# 4               Education        99600          13.92                 0.195
# 6        Home Improvement        45600          11.02                 0.429
# 19     Debt Consolidation        50400          16.13                 0.053
# 20       Home Improvement        96000          11.05                 0.140
# ...                   ...          ...            ...                   ...
# 49987            Business        55200          11.54                 0.381
# 49992             Medical        32100          14.98                 0.253
# 49994            Personal        41600          15.42                 0.434
# 49998            Personal         1400          14.71                 0.451
# 49999            Personal        41000          12.39                 0.057
#
#        loan_to_income_ratio  payment_to_income_ratio  loan_status
# 1                     1.237                    0.412            0
# 4                     1.565                    0.522            1
# 6                     1.014                    0.338            1
# 19                    0.911                    0.304            0
# 20                    1.264                    0.421            1
# ...                     ...                      ...          ...
# 49987                 1.708                    0.569            0
# 49992                 1.295                    0.432            0
# 49994                 0.647                    0.216            0
# 49998                 0.081                    0.027            0
# 49999                 0.874                    0.291            1
#
# [17523 rows x 19 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17523 entries, 1 to 49999
# Data columns (total 19 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   age                      17523 non-null  int64
#  1   occupation_status        17523 non-null  object
#  2   years_employed           17523 non-null  float64
#  3   annual_income            17523 non-null  int64
#  4   credit_score             17523 non-null  int64
#  5   credit_history_years     17523 non-null  float64
#  6   savings_assets           17523 non-null  int64
#  7   current_debt             17523 non-null  int64
#  8   defaults_on_file         17523 non-null  int64
#  9   delinquencies_last_2yrs  17523 non-null  int64
#  10  derogatory_marks         17523 non-null  int64
#  11  product_type             17523 non-null  object
#  12  loan_intent              17523 non-null  object
#  13  loan_amount              17523 non-null  int64
#  14  interest_rate            17523 non-null  float64
#  15  debt_to_income_ratio     17523 non-null  float64
#  16  loan_to_income_ratio     17523 non-null  float64
#  17  payment_to_income_ratio  17523 non-null  float64
#  18  loan_status              17523 non-null  int64
# dtypes: float64(6), int64(10), object(3)
# memory usage: 2.7+ MB

# %%
# Variables numéricas
num_cols = df.select_dtypes(include=['int64', 'float64']).columns

# Variables categóricas
cat_cols = df.select_dtypes(include=['object', 'category']).columns

# Cantidades
print("Numéricas:", len(num_cols))
print("Categóricas:", len(cat_cols))
# Out:
# Numéricas: 16
# Categóricas: 3

# %%
df.describe()
# Out:
#                 age  years_employed  annual_income  credit_score  \
# count  17523.000000    17523.000000   17523.000000  17523.000000
# mean      35.060948        7.531998   50196.296810    643.977116
# std       11.224705        7.699073   32511.053497     64.673587
# min       18.000000        0.000000   15000.000000    375.000000
# 25%       26.000000        1.300000   27389.000000    600.000000
# 50%       35.000000        4.900000   41986.000000    643.000000
# 75%       43.000000       11.600000   62953.500000    688.000000
# max       70.000000       39.900000  250000.000000    850.000000
#
#        credit_history_years  savings_assets   current_debt  defaults_on_file  \
# count          17523.000000    17523.000000   17523.000000      17523.000000
# mean               8.246710     3660.006905   14249.917252          0.051818
# std                7.248336    13353.740340   13123.845785          0.221665
# min                0.000000        0.000000      60.000000          0.000000
# 25%                2.000000      131.500000    5555.000000          0.000000
# 50%                6.200000      585.000000   10411.000000          0.000000
# 75%               12.700000     2347.000000   18423.000000          0.000000
# max               30.000000   300000.000000  135855.000000          1.000000
#
#        delinquencies_last_2yrs  derogatory_marks    loan_amount  \
# count             17523.000000      17523.000000   17523.000000
# mean                  0.557096          0.148491   44278.182960
# std                   0.846501          0.416640   31188.992122
# min                   0.000000          0.000000    1000.000000
# 25%                   0.000000          0.000000   18200.000000
# 50%                   0.000000          0.000000   36900.000000
# 75%                   1.000000          0.000000   67100.000000
# max                   7.000000          4.000000  100000.000000
#
#        interest_rate  debt_to_income_ratio  loan_to_income_ratio  \
# count   17523.000000          17523.000000          17523.000000
# mean       13.185829              0.284400              0.953406
# std         2.195506              0.159057              0.540447
# min         8.000000              0.002000              0.015000
# 25%        11.450000              0.160000              0.497000
# 50%        13.230000              0.263000              0.943000
# 75%        14.990000              0.385000              1.388000
# max        17.000000              0.800000              2.001000
#
#        payment_to_income_ratio   loan_status
# count             17523.000000  17523.000000
# mean                  0.317799      0.480340
# std                   0.180150      0.499628
# min                   0.005000      0.000000
# 25%                   0.166000      0.000000
# 50%                   0.314000      0.000000
# 75%                   0.463000      1.000000
# max                   0.667000      1.000000

# %%
df.shape
# Out:
# (17523, 23)

# %%
df['loan_status'].value_counts()
# Out:
# loan_status
# 0    9106
# 1    8417
# Name: count, dtype: int64

# %%
df['loan_status'].value_counts(normalize=True)
# Out:
# loan_status
# 0    0.51966
# 1    0.48034
# Name: proportion, dtype: float64

# %% [markdown]
# ---

# %% [markdown]
# ### Matriz de Correlación

# %%
df = pd.read_csv("dataset.csv")
df = df.drop(columns=["Unnamed: 0"], errors="ignore")
df.keys()
# Out:
# Index(['age', 'occupation_status', 'years_employed', 'annual_income',
#        'credit_score', 'credit_history_years', 'savings_assets',
#        'current_debt', 'defaults_on_file', 'delinquencies_last_2yrs',
#        'derogatory_marks', 'product_type', 'loan_intent', 'loan_amount',
#        'interest_rate', 'debt_to_income_ratio', 'loan_to_income_ratio',
#        'payment_to_income_ratio', 'loan_status'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17523 entries, 0 to 17522
# Data columns (total 19 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   age                      17523 non-null  int64
#  1   occupation_status        17523 non-null  object
#  2   years_employed           17523 non-null  float64
#  3   annual_income            17523 non-null  int64
#  4   credit_score             17523 non-null  int64
#  5   credit_history_years     17523 non-null  float64
#  6   savings_assets           17523 non-null  int64
#  7   current_debt             17523 non-null  int64
#  8   defaults_on_file         17523 non-null  int64
#  9   delinquencies_last_2yrs  17523 non-null  int64
#  10  derogatory_marks         17523 non-null  int64
#  11  product_type             17523 non-null  object
#  12  loan_intent              17523 non-null  object
#  13  loan_amount              17523 non-null  int64
#  14  interest_rate            17523 non-null  float64
#  15  debt_to_income_ratio     17523 non-null  float64
#  16  loan_to_income_ratio     17523 non-null  float64
#  17  payment_to_income_ratio  17523 non-null  float64
#  18  loan_status              17523 non-null  int64
# dtypes: float64(6), int64(10), object(3)
# memory usage: 2.5+ MB

# %%
def plot_correlation():

    df = pd.read_csv("dataset.csv")

    df = df.drop(columns=["Unnamed: 0"], errors="ignore")

    cols = [
        'age', 'years_employed', 'annual_income',
            'credit_score', 'credit_history_years', 'savings_assets',
            'current_debt', 'defaults_on_file', 'delinquencies_last_2yrs',
            'derogatory_marks', 'loan_amount',
            'interest_rate', 'debt_to_income_ratio', 'loan_to_income_ratio',
            'payment_to_income_ratio', 'loan_status']

    corr_matrix = df[cols].corr()

    # Plot
    plt.figure(figsize=(12, 8))

    sns.heatmap(
        corr_matrix,
        annot=True,
        cmap="Greys",     
        fmt=".2f",
        linewidths=0.5,
        cbar=True
    )

    plt.title("Correlation Matrix")
    plt.tight_layout()
    plt.show()


plot_correlation()

# %%
import pandas as pd

df = pd.read_csv("results.csv")
df = df.drop(columns=["Unnamed: 0"], errors="ignore")
#df.to_csv("results.csv", index=False)

# %%
df.keys()
# Out:
# Index(['age', 'occupation_status', 'years_employed', 'annual_income',
#        'credit_score', 'credit_history_years', 'savings_assets',
#        'current_debt', 'defaults_on_file', 'delinquencies_last_2yrs',
#        'derogatory_marks', 'product_type', 'loan_intent', 'loan_amount',
#        'interest_rate', 'debt_to_income_ratio', 'loan_to_income_ratio',
#        'payment_to_income_ratio', 'loan_status', 'predicted_pd',
#        'expected_loss', 'decision', 'risk_bucket'],
#       dtype='object')

# %%
df.describe()
# Out:
#                 age  years_employed  annual_income  credit_score  \
# count  17523.000000    17523.000000   17523.000000  17523.000000
# mean      35.060948        7.531998   50196.296810    643.977116
# std       11.224705        7.699073   32511.053497     64.673587
# min       18.000000        0.000000   15000.000000    375.000000
# 25%       26.000000        1.300000   27389.000000    600.000000
# 50%       35.000000        4.900000   41986.000000    643.000000
# 75%       43.000000       11.600000   62953.500000    688.000000
# max       70.000000       39.900000  250000.000000    850.000000
#
#        credit_history_years  savings_assets   current_debt  defaults_on_file  \
# count          17523.000000    17523.000000   17523.000000      17523.000000
# mean               8.246710     3660.006905   14249.917252          0.051818
# std                7.248336    13353.740340   13123.845785          0.221665
# min                0.000000        0.000000      60.000000          0.000000
# 25%                2.000000      131.500000    5555.000000          0.000000
# 50%                6.200000      585.000000   10411.000000          0.000000
# 75%               12.700000     2347.000000   18423.000000          0.000000
# max               30.000000   300000.000000  135855.000000          1.000000
#
#        delinquencies_last_2yrs  derogatory_marks    loan_amount  \
# count             17523.000000      17523.000000   17523.000000
# mean                  0.557096          0.148491   44278.182960
# std                   0.846501          0.416640   31188.992122
# min                   0.000000          0.000000    1000.000000
# 25%                   0.000000          0.000000   18200.000000
# 50%                   0.000000          0.000000   36900.000000
# 75%                   1.000000          0.000000   67100.000000
# max                   7.000000          4.000000  100000.000000
#
#        interest_rate  debt_to_income_ratio  loan_to_income_ratio  \
# count   17523.000000          17523.000000          17523.000000
# mean       13.185829              0.284400              0.953406
# std         2.195506              0.159057              0.540447
# min         8.000000              0.002000              0.015000
# 25%        11.450000              0.160000              0.497000
# 50%        13.230000              0.263000              0.943000
# 75%        14.990000              0.385000              1.388000
# max        17.000000              0.800000              2.001000
#
#        payment_to_income_ratio   loan_status  predicted_pd  expected_loss  \
# count             17523.000000  17523.000000  17523.000000   17523.000000
# mean                  0.317799      0.480340      0.481058    9600.386658
# std                   0.180150      0.499628      0.431732   12795.892668
# min                   0.005000      0.000000      0.000077       0.311645
# 25%                   0.166000      0.000000      0.015723     226.064625
# 50%                   0.314000      0.000000      0.436717    3219.518138
# 75%                   0.463000      1.000000      0.965469   14557.467753
# max                   0.667000      1.000000      0.999483   44957.795441
#
#            decision
# count  17523.000000
# mean       0.491811
# std        0.499947
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        1.000000

# %% [markdown]
# ---
